# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2026.1.4)

# %%
import requests

# %%
URL="https://stephen-king-api.onrender.com/api/books"

res=requests.get(URL)

# %%
json_data=res.json()

# %%
import pandas as pd

df=pd.json_normalize(data["data"])
df=df[['id','Title','Year','ISBN']]

# %%
df
# Out:
#     id          Title  Year               ISBN
# 0    1         Carrie  1974  978-0-385-08695-0
# 1    2    Salem's Lot  1975  978-0-385-00751-1
# 2    3    The Shining  1977  978-0-385-12167-5
# 3    4           Rage  1977  978-0-451-07645-8
# 4    5      The Stand  1978  978-0-385-12168-2
# ..  ..            ...   ...                ...
# 58  59   The Outsider  2018  978-1-50118-098-9
# 59  60      Elevation  2018  978-1-98210-231-9
# 60  61  The Institute  2019  978-1-98211-056-7
# 61  62          Later  2021  978-1-78909-649-1
# 62  63  Billy Summers  2021  978-1-982-17361-6
#
# [63 rows x 4 columns]

# %%
# Web Scraping

import requests

URL="https://www.scrapethissite.com/pages/simple/"
res=requests.get(URL)

# %%
if res.status_code==200:
    print(res.headers)

with open("scraped_data/data1.html", "w",encoding="utf-8") as f:
    f.write(res.text)
# Out:
# {'Date': 'Tue, 10 Mar 2026 10:46:13 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=RU6fOB8BAeY2uEq89PofwuHAm1YFmy5tM0Xqwhm1s3o%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1773139572"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=RU6fOB8BAeY2uEq89PofwuHAm1YFmy5tM0Xqwhm1s3o%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1773139572"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': '9da1bbf96ae5e1e4-MRS', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
# Beautiful Soup
! pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (4.15.0)

# %%
# BeautifulSoup

from bs4 import BeautifulSoup

with open("scraped_data/data1.html","r",encoding="utf-8") as f :
  html_content=f.read()

soup=BeautifulSoup(html_content,"lxml")

# %%
all_h3=soup.find_all("h3")

all_countries=[]
for h3 in all_h3:
    name=(h3.get_text(strip=True) )
  #  print(h3.find_parent("div")["class"])
    if h3:
     population=(h3.find_next("div").select("span.country-population")[0].get_text(strip=True))
  #  print(h3.find_next("div").select_one("span.country-population").get_text(strip=True))

     #print(h3.attrs)  # sare attributes h3 ke print

    all_countries.append([name,population])

    print(h3.children)
# Out:
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EE00>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EE00>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EE00>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EE00>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EE00>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EE00>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EE00>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EE00>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>
# <generator object Tag.children.<locals>.<genexpr> at 0x000001CEC6E0EF80>

# %%
import pandas as pd

df=pd.DataFrame(all_countries,columns=["Name","Population"])

# %%
df.to_csv("cleaned_data/data.csv",index=False)
